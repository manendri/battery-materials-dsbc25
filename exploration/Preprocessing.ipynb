# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Loading QMOF dataset

# %%
# Read the csv file for QMOF dataset
df = pd.read_csv('../data/QMOF/qmof_database/qmof_database/qmof.csv', sep=',')
df
# Out:
# /var/folders/wv/fr4yw5nn3qzctb27hyfl7fzh0000gn/T/ipykernel_12265/4033597631.py:2: DtypeWarning: Columns (40,41,43,44,45,46,47,49,50,51,52,53,55,56,57,65,66,67,68,69,77,78,79,80,81,89,90,91,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/QMOF/qmof_database/qmof_database/qmof.csv', sep=',')
#             qmof_id                                    name  \
# 0      qmof-8a95c27                            ABACUF01_FSR
# 1      qmof-019ba28                              ABALOF_FSR
# 2      qmof-830ed1c                              ABAVIJ_FSR
# 3      qmof-5bd4a24                              ABAVOP_FSR
# 4      qmof-644aab4                              ABAXUZ_FSR
# ...             ...                                     ...
# 20369  qmof-7aebbbb  tobacco_srsb_sym_3_on_2_sym_3_mc_0_L_2
# 20370  qmof-9a04c15  tobacco_srsb_sym_3_on_2_sym_3_mc_0_L_6
# 20371  qmof-0dce90f    tobacco_srsb_sym_3_on_2_sym_3_mc_0__
# 20372  qmof-955fe88  tobacco_srsb_sym_3_on_4_sym_3_mc_0_L_2
# 20373  qmof-6538047  tobacco_srsb_sym_3_on_5_sym_3_mc_0_L_2
#
#             info.formula info.formula_reduced  \
# 0          Ba2CuC6H14O16        Ba2CuC6H14O16
# 1      Cu12C36H56I16N4S4         Cu3C9H14I4NS
# 2         Co4C48H32N8O16          CoC12H8N2O4
# 3         Co4C48H32N8O16          CoC12H8N2O4
# 4        Zn2C50H32N6O8S4       ZnC25H16N3O4S2
# ...                  ...                  ...
# 20369      Cu12C84H60N24             CuC7H5N2
# 20370      Cu12C84H48N60             CuC7H4N5
# 20371      Cu12C60H36N24             CuC5H3N2
# 20372     Cu12C112H72N24          Cu3C28H18N6
# 20373     Cu12C108H72N36             CuC9H6N3
#
#                                         info.mofid.mofid  \
# 0                                                    NaN
# 1                                                    NaN
# 2               [Co].[O-]C(=O)c1ccncc1 MOFid-v1.rtl.cat0
# 3               [Co].[O-]C(=O)c1ccncc1 MOFid-v1.rtl.cat0
# 4                                                    NaN
# ...                                                  ...
# 20369  N1=C[C](C=N1)C=Cc1cc(C=CC2=C[N]N=C2)cc(c1)C=CC...
# 20370  N1=C[C](C=N1)n1nnc(c1)c1cc(cc(c1)c1nnn(c1)C1=C...
# 20371  N1=C[C](C=N1)c1cc(cc(c1)C1=CN=N[CH]1)C1=C[N]N=...
# 20372  N1=C[C](C=N1)C=CC1=CC2=CC(=CC3=CC(=CC(=C1)[C]2...
# 20373  N1=C[C](C=N1)C=Cn1cc2c(c1)c1cn(cc1c1c2cn(c1)C=...
#
#                      info.mofid.mofkey info.mofid.smiles_nodes  \
# 0                                  NaN   ['O', '[Ba]', '[Cu]']
# 1                                  NaN                     NaN
# 2      Co.TWBYWOBDOCUKOW.MOFkey-v1.rtl                ['[Co]']
# 3      Co.TWBYWOBDOCUKOW.MOFkey-v1.rtl                ['[Co]']
# 4                                  NaN            ['[Zn][Zn]']
# ...                                ...                     ...
# 20369  Cu.IBPUNEAULYEGJU.MOFkey-v1.srs                ['[Cu]']
# 20370  Cu.JWLDCPHWRGZUAB.MOFkey-v1.srs                ['[Cu]']
# 20371  Cu.PJSMFZDMZONQKK.MOFkey-v1.srs    ['[Cu]', '[Cu][Cu]']
# 20372  Cu.WCJPEIPZJUESBA.MOFkey-v1.srs                ['[Cu]']
# 20373  Cu.HPUZBJXKDGSLPP.MOFkey-v1.srs    ['[Cu]', '[Cu][Cu]']
#
#                                info.mofid.smiles_linkers  \
# 0                                            ['[O-]C=O']
# 1                                                    NaN
# 2                                  ['[O-]C(=O)c1ccncc1']
# 3                                  ['[O-]C(=O)c1ccncc1']
# 4      ['[O-]C(=O)c1cccc(c1)c1nccs1', 'n1ccc(cc1)c1cc...
# ...                                                  ...
# 20369  ['N1=C[C](C=N1)C=Cc1cc(C=CC2=C[N]N=C2)cc(c1)C=...
# 20370  ['N1=C[C](C=N1)n1nnc(c1)c1cc(cc(c1)c1nnn(c1)C1...
# 20371  ['N1=C[C](C=N1)c1cc(cc(c1)C1=CN=N[CH]1)C1=C[N]...
# 20372  ['N1=C[C](C=N1)C=CC1=CC2=CC(=CC3=CC(=CC(=C1)[C...
# 20373  ['N1=C[C](C=N1)C=Cn1cc2c(c1)c1cn(cc1c1c2cn(c1)...
#
#                                        info.mofid.smiles info.mofid.topology  \
# 0                                    O.[Ba].[Cu].[O-]C=O                 NaN
# 1                                                    NaN                 NaN
# 2                                 [Co].[O-]C(=O)c1ccncc1                 rtl
# 3                                 [Co].[O-]C(=O)c1ccncc1                 rtl
# 4      [O-]C(=O)c1cccc(c1)c1nccs1.[Zn][Zn].n1ccc(cc1)...                 NaN
# ...                                                  ...                 ...
# 20369  N1=C[C](C=N1)C=Cc1cc(C=CC2=C[N]N=C2)cc(c1)C=CC...                 srs
# 20370  N1=C[C](C=N1)n1nnc(c1)c1cc(cc(c1)c1nnn(c1)C1=C...                 srs
# 20371  N1=C[C](C=N1)c1cc(cc(c1)C1=CN=N[CH]1)C1=C[N]N=...                 srs
# 20372  N1=C[C](C=N1)C=CC1=CC2=CC(=CC3=CC(=CC(=C1)[C]2...                 srs
# 20373  N1=C[C](C=N1)C=Cn1cc2c(c1)c1cn(cc1c1c2cn(c1)C=...                 srs
#
#        ...  outputs.hse06.energy_elec  outputs.hse06.net_magmom  \
# 0      ...                        NaN                       NaN
# 1      ...                        NaN                       NaN
# 2      ...                        NaN                       NaN
# 3      ...                        NaN                       NaN
# 4      ...                -811.553859                       0.0
# ...    ...                        ...                       ...
# 20369  ...                        NaN                       NaN
# 20370  ...                        NaN                       NaN
# 20371  ...                        NaN                       NaN
# 20372  ...                        NaN                       NaN
# 20373  ...                        NaN                       NaN
#
#        outputs.hse06.bandgap  outputs.hse06.cbm  outputs.hse06.vbm  \
# 0                        NaN                NaN                NaN
# 1                        NaN                NaN                NaN
# 2                        NaN                NaN                NaN
# 3                        NaN                NaN                NaN
# 4                   2.901747           2.246703          -0.655044
# ...                      ...                ...                ...
# 20369                    NaN                NaN                NaN
# 20370                    NaN                NaN                NaN
# 20371                    NaN                NaN                NaN
# 20372                    NaN                NaN                NaN
# 20373                    NaN                NaN                NaN
#
#       outputs.hse06.directgap  outputs.hse06.bandgap_spins  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                        True                 [None, None]
# ...                       ...                          ...
# 20369                     NaN                          NaN
# 20370                     NaN                          NaN
# 20371                     NaN                          NaN
# 20372                     NaN                          NaN
# 20373                     NaN                          NaN
#
#       outputs.hse06.cbm_spins outputs.hse06.vbm_spins  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                [None, None]            [None, None]
# ...                       ...                     ...
# 20369                     NaN                     NaN
# 20370                     NaN                     NaN
# 20371                     NaN                     NaN
# 20372                     NaN                     NaN
# 20373                     NaN                     NaN
#
#        outputs.hse06.directgap_spins
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                       [None, None]
# ...                              ...
# 20369                            NaN
# 20370                            NaN
# 20371                            NaN
# 20372                            NaN
# 20373                            NaN
#
# [20374 rows x 94 columns]

# %% [markdown]
# ## Handling Nan values
#
# Suggested approach for handling Nan values:
#
# 1. Drop columns with most nan values
# 2. Drop rows with most nan values
# 3. Fill remaining missing values using imputation

# %% [markdown]
# Lets check which columns do we have in the dataset

# %%
print('Total no. of columns:', len(df.columns))
df.columns
# Out:
# Total no. of columns: 94
# Index(['qmof_id', 'name', 'info.formula', 'info.formula_reduced',
#        'info.mofid.mofid', 'info.mofid.mofkey', 'info.mofid.smiles_nodes',
#        'info.mofid.smiles_linkers', 'info.mofid.smiles', 'info.mofid.topology',
#        'info.natoms', 'info.pld', 'info.lcd', 'info.density', 'info.volume',
#        'info.symmetry.spacegroup', 'info.symmetry.spacegroup_number',
#        'info.symmetry.spacegroup_crystal', 'info.symmetry.pointgroup',
#        'info.synthesized', 'info.source', 'info.doi', 'inputs.pbe.theory',
#        'inputs.pbe.pseudopotentials', 'inputs.pbe.encut', 'inputs.pbe.kpoints',
#        'inputs.pbe.gamma', 'inputs.pbe.spin', 'outputs.pbe.energy_total',
#        'outputs.pbe.energy_vdw', 'outputs.pbe.energy_elec',
#        'outputs.pbe.net_magmom', 'outputs.pbe.bandgap', 'outputs.pbe.cbm',
#        'outputs.pbe.vbm', 'outputs.pbe.directgap', 'outputs.pbe.bandgap_spins',
#        'outputs.pbe.cbm_spins', 'outputs.pbe.vbm_spins',
#        'outputs.pbe.directgap_spins', 'inputs.hle17.theory',
#        'inputs.hle17.pseudopotentials', 'inputs.hle17.encut',
#        'inputs.hle17.kpoints', 'inputs.hle17.gamma', 'inputs.hle17.spin',
#        'inputs.hse06_10hf.theory', 'inputs.hse06_10hf.pseudopotentials',
#        'inputs.hse06_10hf.encut', 'inputs.hse06_10hf.kpoints',
#        'inputs.hse06_10hf.gamma', 'inputs.hse06_10hf.spin',
#        'inputs.hse06.theory', 'inputs.hse06.pseudopotentials',
#        'inputs.hse06.encut', 'inputs.hse06.kpoints', 'inputs.hse06.gamma',
#        'inputs.hse06.spin', 'outputs.hle17.energy_total',
#        'outputs.hle17.energy_vdw', 'outputs.hle17.energy_elec',
#        'outputs.hle17.net_magmom', 'outputs.hle17.bandgap',
#        'outputs.hle17.cbm', 'outputs.hle17.vbm', 'outputs.hle17.directgap',
#        'outputs.hle17.bandgap_spins', 'outputs.hle17.cbm_spins',
#        'outputs.hle17.vbm_spins', 'outputs.hle17.directgap_spins',
#        'outputs.hse06_10hf.energy_total', 'outputs.hse06_10hf.energy_vdw',
#        'outputs.hse06_10hf.energy_elec', 'outputs.hse06_10hf.net_magmom',
#        'outputs.hse06_10hf.bandgap', 'outputs.hse06_10hf.cbm',
#        'outputs.hse06_10hf.vbm', 'outputs.hse06_10hf.directgap',
#        'outputs.hse06_10hf.bandgap_spins', 'outputs.hse06_10hf.cbm_spins',
#        'outputs.hse06_10hf.vbm_spins', 'outputs.hse06_10hf.directgap_spins',
#        'outputs.hse06.energy_total', 'outputs.hse06.energy_vdw',
#        'outputs.hse06.energy_elec', 'outputs.hse06.net_magmom',
#        'outputs.hse06.bandgap', 'outputs.hse06.cbm', 'outputs.hse06.vbm',
#        'outputs.hse06.directgap', 'outputs.hse06.bandgap_spins',
#        'outputs.hse06.cbm_spins', 'outputs.hse06.vbm_spins',
#        'outputs.hse06.directgap_spins'],
#       dtype='object')

# %% [markdown]
# #### It would make sense to remove some redundant columns at this stage.
#
# Which columns are most important here?

# %%
columns_to_remove = [
    'name', 'info.formula', 'info.formula_reduced',
       'info.mofid.mofid', 'info.mofid.mofkey', 'info.mofid.smiles_nodes',
       'info.mofid.smiles_linkers', 'info.mofid.smiles', 'inputs.pbe.theory',
       'inputs.pbe.pseudopotentials', 'inputs.pbe.encut', 'inputs.pbe.kpoints',
       'inputs.pbe.gamma', 'inputs.hse06.theory',
       'inputs.hse06.pseudopotentials', 'inputs.hse06.encut', 'inputs.hse06.kpoints',
       'inputs.hse06.gamma', 'inputs.hle17.theory',
       'inputs.hle17.pseudopotentials', 'inputs.hle17.encut', 'inputs.hle17.kpoints',
       'inputs.hle17.gamma', 'inputs.hse06_10hf.theory',
       'inputs.hse06_10hf.pseudopotentials', 'inputs.hse06_10hf.encut', 'inputs.hse06_10hf.kpoints',
       'inputs.hse06_10hf.gamma'
] # Please update based on the columns you want to remove

df.drop(columns_to_remove, axis=1, inplace=True)
print(len(df.columns), 'columns remaining')
# Out:
# 66 columns remaining

# %% [markdown]
# Understand the distribution of nan values

# %%
# How are the nan values distributed in the dataset?
missing_summary = df.isna().sum()
print(missing_summary[missing_summary > 0])  # Show columns with NaN values
# Out:
# info.mofid.topology                   12472
# info.doi                               2097
# inputs.hle17.spin                      9617
# inputs.hse06_10hf.spin                 9562
# inputs.hse06.spin                      9563
# outputs.hle17.energy_total             9617
# outputs.hle17.energy_vdw               9617
# outputs.hle17.energy_elec              9617
# outputs.hle17.net_magmom               9617
# outputs.hle17.bandgap                  9617
# outputs.hle17.cbm                      9617
# outputs.hle17.vbm                      9617
# outputs.hle17.directgap                9617
# outputs.hle17.bandgap_spins            9617
# outputs.hle17.cbm_spins                9617
# outputs.hle17.vbm_spins                9617
# outputs.hle17.directgap_spins          9617
# outputs.hse06_10hf.energy_total        9562
# outputs.hse06_10hf.energy_vdw          9562
# outputs.hse06_10hf.energy_elec         9562
# outputs.hse06_10hf.net_magmom          9562
# outputs.hse06_10hf.bandgap             9562
# outputs.hse06_10hf.cbm                 9562
# outputs.hse06_10hf.vbm                 9562
# outputs.hse06_10hf.directgap           9562
# outputs.hse06_10hf.bandgap_spins       9562
# outputs.hse06_10hf.cbm_spins           9562
# outputs.hse06_10hf.vbm_spins           9562
# outputs.hse06_10hf.directgap_spins     9562
# outputs.hse06.energy_total             9563
# outputs.hse06.energy_vdw               9563
# outputs.hse06.energy_elec              9563
# outputs.hse06.net_magmom               9563
# outputs.hse06.bandgap                  9563
# outputs.hse06.cbm                      9563
# outputs.hse06.vbm                      9563
# outputs.hse06.directgap                9563
# outputs.hse06.bandgap_spins            9563
# outputs.hse06.cbm_spins                9563
# outputs.hse06.vbm_spins                9563
# outputs.hse06.directgap_spins          9563
# dtype: int64

# %%
# Drop Columns with Too Many NaNs (e.g., more than 50%) - may need to modify NaN treatment (i. e. keep pbe and hse06 columns only)

threshold = 0.5 * len(df)
df_cleaned_cols = df.dropna(thresh=threshold, axis=1)
print('Total no. of columns after dropping columns with too many NaNs:', len(df_cleaned_cols.columns), 'out of', len(df.columns))
df_cleaned_cols
# Out:
# Total no. of columns after dropping columns with too many NaNs: 65 out of 66
#             qmof_id  info.natoms  info.pld  info.lcd  info.density  \
# 0      qmof-8a95c27           39   0.68822   1.35480      2.763246
# 1      qmof-019ba28          128   1.18570   2.13507      3.229952
# 2      qmof-830ed1c          108   2.36128   4.21176      1.557644
# 3      qmof-5bd4a24          108   2.14542   3.27957      1.616139
# 4      qmof-644aab4          102   1.33452   2.03948      1.596537
# ...             ...          ...       ...       ...           ...
# 20369  qmof-7aebbbb          180  19.56940  21.72285      0.170101
# 20370  qmof-9a04c15          204  20.80552  23.38392      0.162440
# 20371  qmof-0dce90f          132  10.86124  13.89036      0.380963
# 20372  qmof-955fe88          220  23.17582  24.75512      0.132949
# 20373  qmof-6538047          228  23.34456  26.01099      0.125827
#
#         info.volume info.symmetry.spacegroup  info.symmetry.spacegroup_number  \
# 0        408.857471                      P-1                                2
# 1       1781.965032                   P2_1/c                               14
# 2       1292.643180                       Cc                                9
# 3       1245.856916                   P2_1/c                               14
# 4       1148.155557                      P-1                                2
# ...             ...                      ...                              ...
# 20369  21165.032290                       P1                                1
# 20370  27194.106450                       P1                                1
# 20371   8088.346461                       P1                                1
# 20372  31431.035640                       P1                                1
# 20373  34794.026090                       P1                                1
#
#       info.symmetry.spacegroup_crystal info.symmetry.pointgroup  ...  \
# 0                            triclinic                       -1  ...
# 1                           monoclinic                      2/m  ...
# 2                           monoclinic                        m  ...
# 3                           monoclinic                      2/m  ...
# 4                            triclinic                       -1  ...
# ...                                ...                      ...  ...
# 20369                        triclinic                        1  ...
# 20370                        triclinic                        1  ...
# 20371                        triclinic                        1  ...
# 20372                        triclinic                        1  ...
# 20373                        triclinic                        1  ...
#
#        outputs.hse06.energy_elec outputs.hse06.net_magmom  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                    -811.553859                      0.0
# ...                          ...                      ...
# 20369                        NaN                      NaN
# 20370                        NaN                      NaN
# 20371                        NaN                      NaN
# 20372                        NaN                      NaN
# 20373                        NaN                      NaN
#
#       outputs.hse06.bandgap  outputs.hse06.cbm  outputs.hse06.vbm  \
# 0                       NaN                NaN                NaN
# 1                       NaN                NaN                NaN
# 2                       NaN                NaN                NaN
# 3                       NaN                NaN                NaN
# 4                  2.901747           2.246703          -0.655044
# ...                     ...                ...                ...
# 20369                   NaN                NaN                NaN
# 20370                   NaN                NaN                NaN
# 20371                   NaN                NaN                NaN
# 20372                   NaN                NaN                NaN
# 20373                   NaN                NaN                NaN
#
#        outputs.hse06.directgap  outputs.hse06.bandgap_spins  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                         True                 [None, None]
# ...                        ...                          ...
# 20369                      NaN                          NaN
# 20370                      NaN                          NaN
# 20371                      NaN                          NaN
# 20372                      NaN                          NaN
# 20373                      NaN                          NaN
#
#        outputs.hse06.cbm_spins  outputs.hse06.vbm_spins  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                 [None, None]             [None, None]
# ...                        ...                      ...
# 20369                      NaN                      NaN
# 20370                      NaN                      NaN
# 20371                      NaN                      NaN
# 20372                      NaN                      NaN
# 20373                      NaN                      NaN
#
#        outputs.hse06.directgap_spins
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                       [None, None]
# ...                              ...
# 20369                            NaN
# 20370                            NaN
# 20371                            NaN
# 20372                            NaN
# 20373                            NaN
#
# [20374 rows x 65 columns]

# %%
# Drop rows/mofs with too many NaNs (e.g., more than 5)

df_cleaned_rows = df_cleaned_cols.dropna(thresh=50, axis=0)  # Keep rows with at least 50 non-null values (Rudimentary, more fine tuning needed)
print('Total no. of rows after dropping rows with too many NaNs:', len(df_cleaned_rows), 'out of', len(df))
df_cleaned_rows
# Out:
# Total no. of rows after dropping rows with too many NaNs: 10818 out of 20374
#             qmof_id  info.natoms  info.pld  info.lcd  info.density  \
# 4      qmof-644aab4          102   1.33452   2.03948      1.596537
# 13     qmof-85a8986          108   1.12484   2.84758      2.363811
# 26     qmof-07d3562          132   0.99905   1.95298      2.238027
# 27     qmof-9883029          134   1.13178   2.11419      1.573802
# 29     qmof-f224151          126   1.21638   2.69022      1.873856
# ...             ...          ...       ...       ...           ...
# 15951  qmof-f73a75b           67   1.18551   2.89246      1.495041
# 15954  qmof-600a106           66   1.37328   2.56785      1.711368
# 15955  qmof-64eac3c           74   1.12322   2.17481      1.692097
# 15959  qmof-92305e2          100   1.01659   1.93464      1.892463
# 15961  qmof-55d409b           83   1.28465   1.95192      1.420981
#
#        info.volume info.symmetry.spacegroup  info.symmetry.spacegroup_number  \
# 4      1148.155557                      P-1                                2
# 13     1198.848870                   P2_1/c                               14
# 26     1346.122104                   Pna2_1                               33
# 27     1373.690229                   P2_1/c                               14
# 29     1401.471537                 P2_12_12                               18
# ...            ...                      ...                              ...
# 15951   707.036341                      P-1                                2
# 15954   786.642474                       Pc                                7
# 15955   755.001744                      P-1                                2
# 15959  1095.155492                     C2/c                               15
# 15961   799.593592                      P-1                                2
#
#       info.symmetry.spacegroup_crystal info.symmetry.pointgroup  ...  \
# 4                            triclinic                       -1  ...
# 13                          monoclinic                      2/m  ...
# 26                        orthorhombic                      mm2  ...
# 27                          monoclinic                      2/m  ...
# 29                        orthorhombic                      222  ...
# ...                                ...                      ...  ...
# 15951                        triclinic                       -1  ...
# 15954                       monoclinic                        m  ...
# 15955                        triclinic                       -1  ...
# 15959                       monoclinic                      2/m  ...
# 15961                        triclinic                       -1  ...
#
#        outputs.hse06.energy_elec outputs.hse06.net_magmom  \
# 4                    -811.553859                      0.0
# 13                   -885.317539                      0.0
# 26                   -988.564497                      0.0
# 27                  -1044.620530                      0.0
# 29                   -907.691150                      0.0
# ...                          ...                      ...
# 15951                -536.320647                      0.0
# 15954                -524.633244                      0.0
# 15955                -574.486836                      0.0
# 15959                -807.094882                      0.0
# 15961                -625.186032                      1.0
#
#       outputs.hse06.bandgap  outputs.hse06.cbm  outputs.hse06.vbm  \
# 4                  2.901747           2.246703          -0.655044
# 13                 3.742023           1.701769          -2.040254
# 26                 4.504094           2.941661          -1.562433
# 27                 3.511018           3.183242          -0.327776
# 29                 3.807474           2.708256          -1.099218
# ...                     ...                ...                ...
# 15951              2.518369           2.654818           0.136449
# 15954              2.149613           1.953162          -0.196451
# 15955              3.956167           2.750360          -1.205807
# 15959              4.557899           3.212936          -1.344963
# 15961              3.713703           2.667798          -1.045905
#
#        outputs.hse06.directgap  outputs.hse06.bandgap_spins  \
# 4                         True                 [None, None]
# 13                        True                 [None, None]
# 26                        True                 [None, None]
# 27                        True                 [None, None]
# 29                       False                 [None, None]
# ...                        ...                          ...
# 15951                    False                 [None, None]
# 15954                    False                 [None, None]
# 15955                     True                 [None, None]
# 15959                     True                 [None, None]
# 15961                     True         [4.513736, 3.741759]
#
#        outputs.hse06.cbm_spins  outputs.hse06.vbm_spins  \
# 4                 [None, None]             [None, None]
# 13                [None, None]             [None, None]
# 26                [None, None]             [None, None]
# 27                [None, None]             [None, None]
# 29                [None, None]             [None, None]
# ...                        ...                      ...
# 15951             [None, None]             [None, None]
# 15954             [None, None]             [None, None]
# 15955             [None, None]             [None, None]
# 15959             [None, None]             [None, None]
# 15961     [3.467831, 2.667798]   [-1.045905, -1.073961]
#
#        outputs.hse06.directgap_spins
# 4                       [None, None]
# 13                      [None, None]
# 26                      [None, None]
# 27                      [None, None]
# 29                      [None, None]
# ...                              ...
# 15951                   [None, None]
# 15954                   [None, None]
# 15955                   [None, None]
# 15959                   [None, None]
# 15961                  [False, True]
#
# [10818 rows x 65 columns]

# %% [markdown]
# #### Pattern of NaNs
# Are the missing entries structured in some way? How many different types of 'profiles' of missing entries across rows appear in the dataset? And how many rows have each profile type?
#
# From a quick visual inspection of the data: if a row has missing entries, they seem to be missing in 'chunks', in which entries all appear or are all missing. It turns out (as is shown below) that the chunks correspond the different DFT calculations, which is made clear by looking at the column names. We start by spliting the columns into two categories (info and DFT) and extracting the prefix of each column:

# %%
# separate 'info' columns from 'DFT input/output' columns
info_column_names = [cn for cn in df.columns if cn == 'qmof_id' or cn == 'name' or cn.startswith('info')]
dft_column_names = [cn for cn in df.columns if cn.startswith('inputs') or cn.startswith('outputs')]

# Do info_column_names and dft_column_names cover all columns?
set(info_column_names + dft_column_names) == set(df.columns)
# Out:
# True

# %%
# define a function to get the prefix of column name, i.e. part of the column name before the last '.' or the whole column name if it contains no '.'
def get_column_prefix(cn):
    if '.' in cn:
        return '.'.join(cn.split('.')[:-1])
    else:
        return cn

# list of unique DFT column  prefixes
dft_column_prefixes = list(dict.fromkeys([get_column_prefix(cn) for cn in dft_column_names]))
dft_column_prefixes
# Out:
# ['inputs.pbe',
#  'outputs.pbe',
#  'inputs.hle17',
#  'inputs.hse06_10hf',
#  'inputs.hse06',
#  'outputs.hle17',
#  'outputs.hse06_10hf',
#  'outputs.hse06']

# %% [markdown]
# The image plot below represents all 'profiles' of the rows of the original data frame, restricted to the DFT (i.e., 'inputs.\*' and 'outputs,\*') columns. Each row in the image shows the number of data rows with that profile and the profile itself. The color of each entry in the profile is either red (if those data rows have that entry missing) or colored according to the column prefix (if the entry is present).
#
# Importantly, this image shows that the dataset is not randomly / spordaically missing entries. Rather, for some MOFs, only a subset of the DFT calculations were completed. (In fact there are 2^3 = 8 different profiles, which is the number of subsets of a set of 3 members - the 'pbe' cacluation was always done, but the other 3 DFT calculation may or may not have been done, and all combinations appear in the dataset.) This seems to be an already very clean, but heterogeneous, dataset.

# %%
# a data frame with the same shape as the original, restricted to the DFT columns, but with entries replaced with an index: 0 if the entry was NaN or a positive integer representing the column prefix if not
notna_column_prefix_id_df = pd.DataFrame(
   np.array([dft_column_prefixes.index(get_column_prefix(cn)) + 1 for cn in dft_column_names]).reshape(1,len(dft_column_names)).repeat(df.shape[0],axis=0),
    columns = dft_column_names
) * df[dft_column_names].notna()

# tally of idential rows in the above data frame (note: the tally is in the 'size' column of this data frame)
tally_inout_df = notna_column_prefix_id_df.groupby(dft_column_names,as_index=False).size().sort_values(by='size',ascending=False)

# plot the tally data frame as a image
plt.figure(figsize=(10,5))

plt.imshow(np.array(tally_inout_df)[:,:-1], cmap = 'Set1')
plt.xlim(left=-25)
for i, tally in enumerate(tally_inout_df['size']):
    plt.text(-23,i,'number of rows: ' + str(tally), verticalalignment = 'center')

ax = plt.gca()
ax.set_aspect(5)
ax.set_xticks([])
ax.set_yticks([])
ax.set_xticks(np.arange(-.5,len(dft_column_names)+.5, 1), minor=True)
ax.set_yticks(np.arange(.5,7.5, 1), minor=True)
ax.tick_params(axis='both',which='minor',length=0)
plt.grid(visible=True, color='black', linewidth = .4, axis='both', which = 'minor')

cbar = plt.colorbar()
cbar.ax.set_yticks(np.arange(0, len(dft_column_prefixes)+1, 1))
cbar.ax.set_yticklabels(['missing entry'] + ['column = '+prefix+'.*' for prefix in dft_column_prefixes])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# out of all the 'info' columns, there are only missing entries in the 'info.mofid.topology	' and 'info.doi' columns  (note: the tally is in the 'size' column of this data frame)
df.notna().groupby(info_column_names,as_index=False).size().sort_values(by='size',ascending=False)
# Out:
#    qmof_id  info.mofid.topology  info.natoms  info.pld  info.lcd  \
# 1     True                False         True      True      True
# 3     True                 True         True      True      True
# 0     True                False         True      True      True
# 2     True                 True         True      True      True
#
#    info.density  info.volume  info.symmetry.spacegroup  \
# 1          True         True                      True
# 3          True         True                      True
# 0          True         True                      True
# 2          True         True                      True
#
#    info.symmetry.spacegroup_number  info.symmetry.spacegroup_crystal  \
# 1                             True                              True
# 3                             True                              True
# 0                             True                              True
# 2                             True                              True
#
#    info.symmetry.pointgroup  info.synthesized  info.source  info.doi   size
# 1                      True              True         True      True  11105
# 3                      True              True         True      True   7172
# 0                      True              True         True     False   1367
# 2                      True              True         True     False    730

# %% [markdown]
# #### Fill missing values with imputation

# %% [markdown]
# What do we want to impute our data with?
#
# Options:
#
# 1. Mean of the available values for that feature
# 2. Median
# 3. Mode
# 4. A specific value?
